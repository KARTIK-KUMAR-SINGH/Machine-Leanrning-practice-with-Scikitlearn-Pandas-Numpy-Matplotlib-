# %%
from sklearn.datasets import load_iris
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error , mean_squared_error

# %%
iris = load_iris()
x = iris.data
col_names = iris.feature_names
t_name = iris.target_names
print("collumn_names" , col_names)
print("target_names" , t_name)
print("rows \n" , x [ : 5])
#print(iris.keys())
# Out:
# collumn_names ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# target_names ['setosa' 'versicolor' 'virginica']
# rows
#  [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]

# %%
df = pd.DataFrame(data = iris.data , columns = iris.feature_names)
print(df.head())
print("\n")
print(df.tail())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8

# %%
# pd.reset_option('display.width')
# pd.reset_option('display.max_columns')

print(df.corr())
print(df.describe())
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
#
#                    petal width (cm)
# sepal length (cm)          0.817941
# sepal width (cm)          -0.366126
# petal length (cm)          0.962865
# petal width (cm)           1.000000
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# ...

# %%
petal_width = np.array(df["petal width (cm)"]).reshape(-1 , 1)
petal_length = np.array(df["petal length (cm)"]).reshape(-1 , 1)

plt.scatter(petal_width , petal_length , c = "r")
#plt.plot(petal_width , petal_length , c = "b")
plt.show()

# %%
x_train , x_test , y_train , y_test = train_test_split(petal_width , petal_length , test_size = 0.2)
model  = LinearRegression()
model.fit(x_train , y_train)
print(model.coef_)
print(model.intercept_)
# Out:
# [[2.22793206]]
# [1.07607746]

# %%
y_pred = model.predict(x_test)
validating = pd.DataFrame({'Actual_x_test' : x_test.squeeze() , 'Actual_y_test' : y_test.squeeze() , 'Predicted_y_pred' : y_pred.squeeze()})
print(validating)
# Out:
#     Actual_x_test  Actual_y_test  Predicted_y_pred
# 0             1.0            4.0          3.304010
# 1             0.3            1.4          1.744457
# 2             1.1            3.9          3.526803
# 3             1.7            5.0          4.863562
# 4             0.2            1.5          1.521664
# 5             2.0            5.2          5.531942
# 6             1.8            4.8          5.086355
# 7             0.4            1.6          1.967250
# 8             2.3            6.1          6.200321
# 9             1.5            4.5          4.417976
# 10            1.5            5.0          4.417976
# 11            0.1            1.1          1.298871
# 12            1.4            4.8          4.195182
# 13            1.0            3.3          3.304010
# 14            0.2            1.3          1.521664
# 15            2.5            6.1          6.645908
# 16            0.1            1.5          1.298871
# ...

# %%
w = model.coef_
b = model.intercept_
x = float(input("Enter the vaue of petal width and get the predicted value of petal length :- "))


def user_input(w , b , x) :
    predicting = w*x + b
    print(predicting)

user_input(w , b , x)
# Out:
# [[4.19518235]]

# %%
mae = mean_absolute_error(y_test , y_pred)
mse = mean_squared_error(y_test , y_pred)
rmse = np.sqrt(mse)
print(mae)
print(mse)
print(rmse)
# Out:
# 0.2552970009480353
# 0.1018466169822588
# 0.3191341676822756
