# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# LINEAR REGRESSION

# %%
df = pd.read_csv("Salary_dataset.csv")
X = np.array(df["YearsExperience"]).reshape(-1 , 1)
y = np.array(df["Salary"]).reshape(-1 , 1)\

#print(X)
#print(X.shape)
#print(Y)
#print(y.shape)

plt.scatter(X , y , c = 'r')
plt.plot(X , y , c = 'b')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
X_train , X_test , y_train , y_test = train_test_split(X , y , test_size = 0.20)
model = LinearRegression()
model.fit(X_train , y_train)

y_pred = model.predict(X_test)

plt.scatter(X , y , c = "r")
plt.plot(X , y , c = "b")
plt.plot(X_test , y_pred , c = "g" , linewidth = 3)
#plt.plot(X_test , y_test , c = "y" , linewidth = 5)
plt.show()

# %%
plt.scatter(X , y , c = "r")
plt.plot(X , y , c = "b")
plt.plot(X_test , y_test , c = "y" , linewidth = 5)
plt.show()

# %% [markdown]
# POLYNOMIAL REGRESSION

# %%
X_train1 , X_test1 , y_train1 , y_test1 = train_test_split(X, y , test_size = 0.20)
poly = PolynomialFeatures(degree = 5)
X_train_poly = poly.fit_transform(X_train1)
X_test_poly = poly.fit_transform(X_test1)

model2 = LinearRegression()
model.fit(X_train_poly , y_train1)
y_pred = model.predict(X_test_poly)

#sorting
sorted_indices = np.argsort(X_test1.flatten())
X_test_sorted = X_test1[sorted_indices]
Y_test_sorted = y_test1[sorted_indices]
Y_pred_sorted = y_pred[sorted_indices]


plt.scatter(X , y , c = "r")
plt.plot(X , y , c = 'b')
plt.plot(X_test_sorted , Y_pred_sorted , c = 'g' , linewidth = 3)
plt.show()
